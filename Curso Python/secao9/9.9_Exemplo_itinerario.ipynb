# %% [markdown]
# ## 9.9 Tratando dados de intinerários (Exemplo prático 2)
#
# Dados horários de intinerários, pede-se:
# - Encontre e filtre as razões sociais que se repetem duas vezes;
# - Encontre quais delas possuem intervalos em menos de uma hora.
#
# https://dados.antt.gov.br/dataset/gerenciamento-de-autorizacoes
#
# Uso do método **.isin** e da função **pd.to_datetime**

# %%
import pandas as pd

file = 'horarios.csv'

df = pd.read_csv(file, sep=';', encoding='ISO-8859-1', engine='python')

df.head()
# Out:
#                  cnpj                     razao_social data_autorizacao  \
# 0  04.192.453/0001-18  ALFA LUZ VIACAO TRANSPORTE LTDA       08/07/2016
# 1  04.192.453/0001-18  ALFA LUZ VIACAO TRANSPORTE LTDA       08/07/2016
# 2  04.192.453/0001-18  ALFA LUZ VIACAO TRANSPORTE LTDA       06/11/2018
# 3  04.192.453/0001-18  ALFA LUZ VIACAO TRANSPORTE LTDA       06/11/2018
# 4  04.192.453/0001-18  ALFA LUZ VIACAO TRANSPORTE LTDA       15/05/2017
#
#       prefixo                  descricao_linha          tipo_veiculo sentido  \
# 0  12-0140-00  BRASILIA(DF) - CALDAS NOVAS(GO)  CONVEN. C/ SANITÁRIO     ida
# 1  12-0140-00  BRASILIA(DF) - CALDAS NOVAS(GO)  CONVEN. C/ SANITÁRIO   volta
# 2  12-0140-61  BRASILIA(DF) - CALDAS NOVAS(GO)             EXECUTIVO     ida
# 3  12-0140-61  BRASILIA(DF) - CALDAS NOVAS(GO)             EXECUTIVO   volta
# 4  12-0274-00  CALDAS NOVAS(GO) - ARAGUARI(MG)  CONVEN. C/ SANITÁRIO     ida
#
#   horario segunda_feira terca_feira  ... marco abril maio junho julho agosto  \
# 0   14:00             x           x  ...     x     x    x     x     x      x
# 1   07:00             x           x  ...     x     x    x     x     x      x
# 2   07:30             x           x  ...     x     x    x     x     x      x
# 3   14:00             x           x  ...     x     x    x     x     x      x
# 4   06:45           NaN         NaN  ...     x     x    x     x     x      x
#
#   setembro outubro novembro dezembro
# 0        x       x        x        x
# 1        x       x        x        x
# 2        x       x        x        x
# 3        x       x        x        x
# 4        x       x        x        x
#
# [5 rows x 27 columns]

# %%
df['time'] = pd.to_datetime(df['horario'])

df.head(2)
# Out:
# C:\Users\bgran\AppData\Local\Temp\ipykernel_14916\3069118105.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['time'] = pd.to_datetime(df['horario'])
#                  cnpj                     razao_social data_autorizacao  \
# 0  04.192.453/0001-18  ALFA LUZ VIACAO TRANSPORTE LTDA       08/07/2016
# 1  04.192.453/0001-18  ALFA LUZ VIACAO TRANSPORTE LTDA       08/07/2016
#
#       prefixo                  descricao_linha          tipo_veiculo sentido  \
# 0  12-0140-00  BRASILIA(DF) - CALDAS NOVAS(GO)  CONVEN. C/ SANITÁRIO     ida
# 1  12-0140-00  BRASILIA(DF) - CALDAS NOVAS(GO)  CONVEN. C/ SANITÁRIO   volta
#
#   horario segunda_feira terca_feira  ... abril maio junho julho agosto  \
# 0   14:00             x           x  ...     x    x     x     x      x
# 1   07:00             x           x  ...     x    x     x     x      x
#
#   setembro outubro novembro dezembro                time
# 0        x       x        x        x 2025-03-15 14:00:00
# 1        x       x        x        x 2025-03-15 07:00:00
#
# [2 rows x 28 columns]

# %%
df['time'][1]-df['time'][2]
# Out:
# Timedelta('-1 days +23:30:00')

# %%
filtro_2 = df['razao_social'].value_counts() == 2
lista_filtrada = list(filtro_2[filtro_2].index)
print(len(lista_filtrada))
lista_filtrada
# Out:
# 16
# ['DANISTUR TRANSPORTE RODOVIARIO LTDA',
#  'EXPRESSO SANTA MARTA LTDA.',
#  'EXPRESSO METRÓPOLIS TRANSPORTES E VIAGENS LTDA.',
#  'EXPRESSO BRASILEIRO TRANSPORTE RODOVIARIO E TURISMO LTDA - EPP',
#  'EMPRESA TESTE SUPAS',
#  'JS SERVIÇOS LOGISTICOS LTDA',
#  'IVAIR CAETANO DO NASCIMENTO ? ME',
#  'IRMÃOS NASCIMENTO TURISMO LTDA.',
#  'KAWAGUCHI EVENTOS TRANSPORTE E TURISMO LTDA. (CATEDRAL TURISMO)',
#  'TRANSPEN TRANSPORTE COLETIVO E ENCOMENDAS LTDA.',
#  'TPC TRANSPORTES LTDA - ME',
#  'ROTA DO SOL TRANSPORTE E TURISMO LTDA',
#  'VIAÇÃO MINEIROS TRANSPORTE E TURISMO LTDA',
#  'VIAÇÃO LUXOR LTDA - LLC TRANSPORTES',
#  'VIACAO JLS LTDA',
#  'VIAÇÃO TERESÓPOLIS E TURISMO LTDA.']

# %%
print(df['razao_social'].isin(lista_filtrada).value_counts())

tabela_filtrada = df[df['razao_social'].isin(lista_filtrada)]
tabela_filtrada
# Out:
# razao_social
# False    11445
# True        32
# Name: count, dtype: int64
#                      cnpj                                       razao_social  \
# 1792   04.801.028/0001-89                DANISTUR TRANSPORTE RODOVIARIO LTDA
# 1793   04.801.028/0001-89                DANISTUR TRANSPORTE RODOVIARIO LTDA
# 2934   76.423.366/0001-35                                EMPRESA TESTE SUPAS
# 2935   76.423.366/0001-35                                EMPRESA TESTE SUPAS
# 3189   02.840.960/0001-95  EXPRESSO BRASILEIRO TRANSPORTE RODOVIARIO E TU...
# 3190   02.840.960/0001-95  EXPRESSO BRASILEIRO TRANSPORTE RODOVIARIO E TU...
# 3809   05.939.969/0001-46    EXPRESSO METRÓPOLIS TRANSPORTES E VIAGENS LTDA.
# 3810   05.939.969/0001-46    EXPRESSO METRÓPOLIS TRANSPORTES E VIAGENS LTDA.
# 3850   01.526.151/0001-40                         EXPRESSO SANTA MARTA LTDA.
# 3851   01.526.151/0001-40                         EXPRESSO SANTA MARTA LTDA.
# 4515   02.909.758/0001-72                    IRMÃOS NASCIMENTO TURISMO LTDA.
# 4516   02.909.758/0001-72                    IRMÃOS NASCIMENTO TURISMO LTDA.
# 4517   05.768.137/0001-04                   IVAIR CAETANO DO NASCIMENTO ? ME
# 4518   05.768.137/0001-04                   IVAIR CAETANO DO NASCIMENTO ? ME
# 4877   10.918.268/0001-60                        JS SERVIÇOS LOGISTICOS LTDA
# 4878   10.918.268/0001-60                        JS SERVIÇOS LOGISTICOS LTDA
# 5008   07.620.023/0001-48  KAWAGUCHI EVENTOS TRANSPORTE E TURISMO LTDA. (...
# 5009   07.620.023/0001-48  KAWAGUCHI EVENTOS TRANSPORTE E TURISMO LTDA. (...
# 6934   03.103.551/0001-79              ROTA DO SOL TRANSPORTE E TURISMO LTDA
# 6935   03.103.551/0001-79              ROTA DO SOL TRANSPORTE E TURISMO LTDA
# 7494   01.718.370/0001-21                          TPC TRANSPORTES LTDA - ME
# 7495   01.718.370/0001-21                          TPC TRANSPORTES LTDA - ME
# 7641   75.156.265/0001-82    TRANSPEN TRANSPORTE COLETIVO E ENCOMENDAS LTDA.
# 7642   75.156.265/0001-82    TRANSPEN TRANSPORTE COLETIVO E ENCOMENDAS LTDA.
# 9866   26.428.813/0001-70                                    VIACAO JLS LTDA
# 9867   26.428.813/0001-70                                    VIACAO JLS LTDA
# 9868   26.760.933/0001-70                VIAÇÃO LUXOR LTDA - LLC TRANSPORTES
# 9869   26.760.933/0001-70                VIAÇÃO LUXOR LTDA - LLC TRANSPORTES
# 9870   09.574.438/0001-58          VIAÇÃO MINEIROS TRANSPORTE E TURISMO LTDA
# 9871   09.574.438/0001-58          VIAÇÃO MINEIROS TRANSPORTE E TURISMO LTDA
# 11277  32.179.061/0001-54                 VIAÇÃO TERESÓPOLIS E TURISMO LTDA.
# 11278  32.179.061/0001-54                 VIAÇÃO TERESÓPOLIS E TURISMO LTDA.
#
#       data_autorizacao     prefixo  \
# 1792        22/04/2020  12-0489-60
# 1793        22/04/2020  12-0489-60
# 2934        22/09/2020  06-1863-00
# 2935        22/09/2020  06-1863-00
# 3189        28/01/2020  12-9614-00
# 3190        28/01/2020  12-9614-00
# 3809        08/07/2016  08-0006-20
# 3810        08/07/2016  08-0006-20
# 3850        10/04/2008  11-9057-00
# 3851        10/04/2008  11-9057-00
# 4515        27/04/2010  05-9178-00
# 4516        27/04/2010  05-9178-00
# 4517        30/07/2012  06-9316-00
# 4518        30/07/2012  06-9316-00
# 4877        09/10/2017  18-0015-00
# 4878        09/10/2017  18-0015-00
# 5008        20/09/2013  12-9370-00
# 5009        20/09/2013  12-9370-00
# 6934        09/04/2014  12-5026-70
# 6935        09/04/2014  12-5026-70
# 7494        22/07/2016  05-0120-00
# 7495        22/07/2016  05-0120-00
# 7641        01/07/2005  09-1363-02
# 7642        01/07/2005  09-1363-02
# 9866        20/12/2006  12-9039-00
# 9867        20/12/2006  12-9039-00
# 9868        28/09/2020  06-0434-00
# 9869        28/09/2020  06-0434-00
# 9870        18/06/2015  11-9587-00
# 9871        18/06/2015  11-9587-00
# 11277       01/07/2016  07-0045-00
# 11278       01/07/2016  07-0045-00
#
#                                   descricao_linha          tipo_veiculo  \
# 1792                   GOIANIA(GO) - XINGUARA(PA)             EXECUTIVO
# 1793                   GOIANIA(GO) - XINGUARA(PA)             EXECUTIVO
# 2934                 PIAU(MG) - AGUA COMPRIDA(MG)  CONVEN. C/ SANITÁRIO
# 2935                 PIAU(MG) - AGUA COMPRIDA(MG)  CONVEN. C/ SANITÁRIO
# 3189              PIRES DO RIO(GO) - SAO LUIS(MA)  CONVEN. C/ SANITÁRIO
# 3190              PIRES DO RIO(GO) - SAO LUIS(MA)  CONVEN. C/ SANITÁRIO
# 3809                 CAMPINAS(SP) - OURO FINO(MG)  CONVEN. S/ SANITÁRIO
# 3810                 CAMPINAS(SP) - OURO FINO(MG)  CONVEN. S/ SANITÁRIO
# 3850           BARRA DO GARCAS(MT) - ANAPOLIS(GO)  CONVEN. C/ SANITÁRIO
# 3851           BARRA DO GARCAS(MT) - ANAPOLIS(GO)  CONVEN. C/ SANITÁRIO
# 4515         GUAJERU(BA) - SAO CAETANO DO SUL(SP)  CONVEN. C/ SANITÁRIO
# 4516         GUAJERU(BA) - SAO CAETANO DO SUL(SP)  CONVEN. C/ SANITÁRIO
# 4517                 NOVA BELEM(MG) - VITORIA(ES)  CONVEN. C/ SANITÁRIO
# 4518                 NOVA BELEM(MG) - VITORIA(ES)  CONVEN. C/ SANITÁRIO
# 4877                  FLORIANO(PI) - SAO LUIS(MA)  CONVEN. C/ SANITÁRIO
# 4878                  FLORIANO(PI) - SAO LUIS(MA)  CONVEN. C/ SANITÁRIO
# 5008                TAGUATINGA(DF) - TRINDADE(GO)  CONVEN. C/ SANITÁRIO
# 5009                TAGUATINGA(DF) - TRINDADE(GO)  CONVEN. C/ SANITÁRIO
# 6934                 LAGO AZUL(GO) - BRASILIA(DF)           SEMI-URBANO
# 6935                 LAGO AZUL(GO) - BRASILIA(DF)           SEMI-URBANO
# 7494                      ABAIRA(BA) - SANTOS(SP)  CONVEN. C/ SANITÁRIO
# 7495                      ABAIRA(BA) - SANTOS(SP)  CONVEN. C/ SANITÁRIO
# 7641                  CURITIBA(PR) - CAMPINAS(SP)  CONVEN. C/ SANITÁRIO
# 7642                  CURITIBA(PR) - CAMPINAS(SP)  CONVEN. C/ SANITÁRIO
# 9866   BRASILIA(DF) - CAMPO ALEGRE DE LOURDES(BA)  CONVEN. C/ SANITÁRIO
# 9867   BRASILIA(DF) - CAMPO ALEGRE DE LOURDES(BA)  CONVEN. C/ SANITÁRIO
# 9868               UBERLANDIA(MG) - GUARULHOS(SP)  CONVEN. C/ SANITÁRIO
# 9869               UBERLANDIA(MG) - GUARULHOS(SP)  CONVEN. C/ SANITÁRIO
# 9870          ALTO TAQUARI(MT) - CALDAS NOVAS(GO)  CONVEN. C/ SANITÁRIO
# 9871          ALTO TAQUARI(MT) - CALDAS NOVAS(GO)  CONVEN. C/ SANITÁRIO
# 11277          TERESOPOLIS(RJ) - ALEM PARAIBA(MG)  CONVEN. C/ SANITÁRIO
# 11278          TERESOPOLIS(RJ) - ALEM PARAIBA(MG)  CONVEN. C/ SANITÁRIO
#
#       sentido horario segunda_feira terca_feira  ... abril maio junho julho  \
# 1792      ida   14:00           NaN           x  ...     x    x     x     x
# 1793    volta   09:30           NaN           x  ...     x    x     x     x
# 2934      ida   13:00             x         NaN  ...     x    x     x     x
# 2935    volta   14:00           NaN           x  ...     x    x     x     x
# 3189      ida   10:30             x           x  ...     x    x     x     x
# 3190    volta   17:30             x           x  ...     x    x     x     x
# 3809      ida   17:15           NaN         NaN  ...     x    x     x     x
# 3810    volta   07:00             x         NaN  ...     x    x     x     x
# 3850      ida   10:30             x           x  ...     x    x     x     x
# 3851    volta   15:30             x           x  ...     x    x     x     x
# 4515      ida   07:00           NaN         NaN  ...     x    x     x     x
# 4516    volta   07:00           NaN         NaN  ...     x    x     x     x
# 4517      ida   08:00           NaN           x  ...     x    x   NaN   NaN
# 4518    volta   09:00             x         NaN  ...     x    x   NaN   NaN
# 4877      ida   06:00           NaN         NaN  ...     x    x     x     x
# 4878    volta   06:00           NaN         NaN  ...     x    x     x     x
# 5008      ida   06:00             x         NaN  ...     x    x     x     x
# 5009    volta   12:00             x         NaN  ...     x    x     x     x
# 6934      ida   00:00             x           x  ...     x    x     x     x
# 6935    volta   00:00             x           x  ...     x    x     x     x
# 7494      ida   05:00             x         NaN  ...     x    x     x     x
# 7495    volta   04:30           NaN         NaN  ...     x    x     x     x
# 7641      ida   08:30           NaN         NaN  ...     x    x     x     x
# 7642    volta   08:15           NaN         NaN  ...     x    x     x     x
# 9866      ida   12:00           NaN         NaN  ...     x    x     x     x
# 9867    volta   12:00           NaN           x  ...     x    x     x     x
# 9868      ida   22:30           NaN         NaN  ...     x    x     x     x
# 9869    volta   22:30           NaN         NaN  ...     x    x     x     x
# 9870      ida   04:50             x           x  ...     x    x     x     x
# 9871    volta   10:00             x           x  ...     x    x     x     x
# 11277     ida   07:00             x         NaN  ...     x    x     x     x
# 11278   volta   17:00             x         NaN  ...     x    x     x     x
#
#       agosto setembro outubro novembro dezembro                time
# 1792       x        x       x        x        x 2025-03-15 14:00:00
# 1793       x        x       x        x        x 2025-03-15 09:30:00
# 2934       x        x       x        x        x 2025-03-15 13:00:00
# 2935       x        x       x        x        x 2025-03-15 14:00:00
# 3189       x        x       x        x        x 2025-03-15 10:30:00
# 3190       x        x       x        x        x 2025-03-15 17:30:00
# 3809       x        x       x        x        x 2025-03-15 17:15:00
# 3810       x        x       x        x        x 2025-03-15 07:00:00
# 3850       x        x       x        x        x 2025-03-15 10:30:00
# 3851       x        x       x        x        x 2025-03-15 15:30:00
# 4515       x        x       x        x        x 2025-03-15 07:00:00
# 4516       x        x       x        x        x 2025-03-15 07:00:00
# 4517     NaN      NaN     NaN      NaN      NaN 2025-03-15 08:00:00
# 4518     NaN      NaN     NaN      NaN      NaN 2025-03-15 09:00:00
# 4877       x        x       x        x        x 2025-03-15 06:00:00
# 4878       x        x       x        x        x 2025-03-15 06:00:00
# 5008       x        x       x        x        x 2025-03-15 06:00:00
# 5009       x        x       x        x        x 2025-03-15 12:00:00
# 6934       x        x       x        x        x 2025-03-15 00:00:00
# 6935       x        x       x        x        x 2025-03-15 00:00:00
# 7494       x        x       x        x        x 2025-03-15 05:00:00
# 7495       x        x       x        x        x 2025-03-15 04:30:00
# 7641       x        x       x        x        x 2025-03-15 08:30:00
# 7642       x        x       x        x        x 2025-03-15 08:15:00
# 9866       x        x       x        x        x 2025-03-15 12:00:00
# 9867       x        x       x        x        x 2025-03-15 12:00:00
# 9868       x        x       x        x        x 2025-03-15 22:30:00
# 9869       x        x       x        x        x 2025-03-15 22:30:00
# 9870       x        x       x        x        x 2025-03-15 04:50:00
# 9871       x        x       x        x        x 2025-03-15 10:00:00
# 11277      x        x       x        x        x 2025-03-15 07:00:00
# 11278      x        x       x        x        x 2025-03-15 17:00:00
#
# [32 rows x 28 columns]

# %%
Serie_max = pd.pivot_table(tabela_filtrada,index='razao_social',values=['time'],aggfunc='max')
Serie_max
# Out:
#                                                                   time
# razao_social
# DANISTUR TRANSPORTE RODOVIARIO LTDA                2025-03-15 14:00:00
# EMPRESA TESTE SUPAS                                2025-03-15 14:00:00
# EXPRESSO BRASILEIRO TRANSPORTE RODOVIARIO E TUR... 2025-03-15 17:30:00
# EXPRESSO METRÓPOLIS TRANSPORTES E VIAGENS LTDA.    2025-03-15 17:15:00
# EXPRESSO SANTA MARTA LTDA.                         2025-03-15 15:30:00
# IRMÃOS NASCIMENTO TURISMO LTDA.                    2025-03-15 07:00:00
# IVAIR CAETANO DO NASCIMENTO ? ME                   2025-03-15 09:00:00
# JS SERVIÇOS LOGISTICOS LTDA                        2025-03-15 06:00:00
# KAWAGUCHI EVENTOS TRANSPORTE E TURISMO LTDA. (C... 2025-03-15 12:00:00
# ROTA DO SOL TRANSPORTE E TURISMO LTDA              2025-03-15 00:00:00
# TPC TRANSPORTES LTDA - ME                          2025-03-15 05:00:00
# TRANSPEN TRANSPORTE COLETIVO E ENCOMENDAS LTDA.    2025-03-15 08:30:00
# VIACAO JLS LTDA                                    2025-03-15 12:00:00
# VIAÇÃO LUXOR LTDA - LLC TRANSPORTES                2025-03-15 22:30:00
# VIAÇÃO MINEIROS TRANSPORTE E TURISMO LTDA          2025-03-15 10:00:00
# VIAÇÃO TERESÓPOLIS E TURISMO LTDA.                 2025-03-15 17:00:00

# %%
Serie_min = pd.pivot_table(tabela_filtrada,index='razao_social',values=['time'],aggfunc='min')
Serie_min
# Out:
#                                                                   time
# razao_social
# DANISTUR TRANSPORTE RODOVIARIO LTDA                2025-03-15 09:30:00
# EMPRESA TESTE SUPAS                                2025-03-15 13:00:00
# EXPRESSO BRASILEIRO TRANSPORTE RODOVIARIO E TUR... 2025-03-15 10:30:00
# EXPRESSO METRÓPOLIS TRANSPORTES E VIAGENS LTDA.    2025-03-15 07:00:00
# EXPRESSO SANTA MARTA LTDA.                         2025-03-15 10:30:00
# IRMÃOS NASCIMENTO TURISMO LTDA.                    2025-03-15 07:00:00
# IVAIR CAETANO DO NASCIMENTO ? ME                   2025-03-15 08:00:00
# JS SERVIÇOS LOGISTICOS LTDA                        2025-03-15 06:00:00
# KAWAGUCHI EVENTOS TRANSPORTE E TURISMO LTDA. (C... 2025-03-15 06:00:00
# ROTA DO SOL TRANSPORTE E TURISMO LTDA              2025-03-15 00:00:00
# TPC TRANSPORTES LTDA - ME                          2025-03-15 04:30:00
# TRANSPEN TRANSPORTE COLETIVO E ENCOMENDAS LTDA.    2025-03-15 08:15:00
# VIACAO JLS LTDA                                    2025-03-15 12:00:00
# VIAÇÃO LUXOR LTDA - LLC TRANSPORTES                2025-03-15 22:30:00
# VIAÇÃO MINEIROS TRANSPORTE E TURISMO LTDA          2025-03-15 04:50:00
# VIAÇÃO TERESÓPOLIS E TURISMO LTDA.                 2025-03-15 07:00:00

# %%
Serie_max - Serie_min
# Out:
#                                                               time
# razao_social
# DANISTUR TRANSPORTE RODOVIARIO LTDA                0 days 04:30:00
# EMPRESA TESTE SUPAS                                0 days 01:00:00
# EXPRESSO BRASILEIRO TRANSPORTE RODOVIARIO E TUR... 0 days 07:00:00
# EXPRESSO METRÓPOLIS TRANSPORTES E VIAGENS LTDA.    0 days 10:15:00
# EXPRESSO SANTA MARTA LTDA.                         0 days 05:00:00
# IRMÃOS NASCIMENTO TURISMO LTDA.                    0 days 00:00:00
# IVAIR CAETANO DO NASCIMENTO ? ME                   0 days 01:00:00
# JS SERVIÇOS LOGISTICOS LTDA                        0 days 00:00:00
# KAWAGUCHI EVENTOS TRANSPORTE E TURISMO LTDA. (C... 0 days 06:00:00
# ROTA DO SOL TRANSPORTE E TURISMO LTDA              0 days 00:00:00
# TPC TRANSPORTES LTDA - ME                          0 days 00:30:00
# TRANSPEN TRANSPORTE COLETIVO E ENCOMENDAS LTDA.    0 days 00:15:00
# VIACAO JLS LTDA                                    0 days 00:00:00
# VIAÇÃO LUXOR LTDA - LLC TRANSPORTES                0 days 00:00:00
# VIAÇÃO MINEIROS TRANSPORTE E TURISMO LTDA          0 days 05:10:00
# VIAÇÃO TERESÓPOLIS E TURISMO LTDA.                 0 days 10:00:00
