# %% [markdown]
# ## 9.12 Regressão linear com statsmodels
#
# **Estrutura:**
#
# Sejam **X** e **Y** dois arrays, ou Series, ou listas, onde:
#
# $$ Y = cte + cX $$
#
#
#
# ```python
# >>>import statsmodels.api as sm #para importar a biblioteca
# >>>X = sm.add_constant(X) #adiciona a constante da regressão linear, se desejável
# >>>est = sm.OLS(Y,X).fit() #gera o objeto de regressão linear baseada em X e Y
# >>>est.params #retorna os parâmetros da regressão linear
# >>>print(est.summary()) #imprime um relatório estatístico da regressão linear
# ```

# %%
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm

df = pd.DataFrame({'X':[0,1,2,3,4],'Y':[2,3,5,10,15]})

plt.figure()
plt.suptitle('Regressão')
plt.plot(df['X'],df['Y'],'ro')
plt.ylabel('Y')
plt.xlabel('X')

plt.grid()
plt.show()

# %%
X = df['X']
Y = df['Y']

est = sm.OLS(Y,X).fit()

print(est.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      Y   R-squared (uncentered):                   0.974
# Model:                            OLS   Adj. R-squared (uncentered):              0.968
# Method:                 Least Squares   F-statistic:                              151.0
# Date:                Sat, 15 Mar 2025   Prob (F-statistic):                    0.000252
# Time:                        23:15:42   Log-Likelihood:                         -8.6640
# No. Observations:                   5   AIC:                                      19.33
# Df Residuals:                       4   BIC:                                      18.94
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# X              3.4333      0.279     12.289      0.000       2.658       4.209
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.376
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.332
# Skew:                          -0.024   Prob(JB):                        0.847
# Kurtosis:                       1.739   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# C:\Users\bgran\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\statsmodels\stats\stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "

# %%
est.params
# Out:
# X    3.433333
# dtype: float64

# %%
X*3.433333
# Out:
# 0     0.000000
# 1     3.433333
# 2     6.866666
# 3    10.299999
# 4    13.733332
# Name: X, dtype: float64

# %%
est.predict()
# Out:
# array([ 0.        ,  3.43333333,  6.86666667, 10.3       , 13.73333333])

# %%
plt.figure()
plt.suptitle('Regressão')
plt.plot(df['X'],df['Y'],'ro')
plt.plot(df['X'],est.predict(),'k--')
plt.ylabel('Y')
plt.xlabel('X')

plt.grid()
plt.show()

# %%
X = sm.add_constant(X)
Y = df['Y']

est = sm.OLS(Y,X).fit()

print(est.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.923
# Model:                            OLS   Adj. R-squared:                  0.897
# Method:                 Least Squares   F-statistic:                     35.90
# Date:                Sat, 15 Mar 2025   Prob (F-statistic):            0.00931
# Time:                        23:15:42   Log-Likelihood:                -8.5918
# No. Observations:                   5   AIC:                             21.18
# Df Residuals:                       3   BIC:                             20.40
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.4000      1.349      0.296      0.786      -3.893       4.693
# X              3.3000      0.551      5.992      0.009       1.547       5.053
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.402
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.416
# Skew:                          -0.125   Prob(JB):                        0.812
# Kurtosis:                       1.609   Cond. No.                         4.74
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# C:\Users\bgran\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\statsmodels\stats\stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "

# %%
est.params
# Out:
# const    0.4
# X        3.3
# dtype: float64

# %%
X*3.3 + 0.4
# Out:
#    const     X
# 0    3.7   0.4
# 1    3.7   3.7
# 2    3.7   7.0
# 3    3.7  10.3
# 4    3.7  13.6

# %%
est.predict()
# Out:
# array([ 0.4,  3.7,  7. , 10.3, 13.6])

# %%
plt.figure()
plt.suptitle('Regressão')
plt.plot(df['X'],df['Y'],'ro')
plt.plot(df['X'],est.predict(),'k--')
plt.ylabel('Y')
plt.xlabel('X')

plt.grid()
plt.show()
